# %% [markdown]
# # Importing Data Sets

# %%
import pandas as pd 

student_mat = pd.read_csv("student_mat.csv")

student_mat
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import pandas as pd 

student_por = pd.read_csv("student_por.csv")

student_por
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # Cleaning Data Sets

# %%
# Removing Rows That Contain Empty Cells

import pandas as pd 

student_mat = pd.read_csv("student_mat.csv")

student_mat_clean = student_mat.dropna()

print(student_mat_clean.to_string())
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob      reason guardian  traveltime  studytime  failures  schoolsup  famsup   paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  dalc  walc  health  absences  g1  g2  g3
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher      course   mother           2          2         0       True   False  False       False     True    True     False     False       4         3      4     1     1       3         6   5   6   6
# 1       GP   F   17       U     GT3       T     1     1   at_home     other      course   father           1          2         0      False    True  False       False    False    True      True     False       5         3      3     1     1       3         4   5   5   6
# ...

# %%
# Removing Rows That Contain Empty Cells

import pandas as pd 

student_por = pd.read_csv("student_por.csv")

student_por_clean = student_por.dropna()

print(student_por_clean.to_string())
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob      reason guardian  traveltime  studytime  failures  schoolsup  famsup   paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  dalc  walc  health  absences  g1  g2  g3
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher      course   mother           2          2         0       True   False  False       False     True    True     False     False       4         3      4     1     1       3         4   0  11  11
# 1       GP   F   17       U     GT3       T     1     1   at_home     other      course   father           1          2         0      False    True  False       False    False    True      True     False       5         3      3     1     1       3         2   9  11  11
# ...

# %% [markdown]
# # Basic Information

# %% [markdown]
# ## Columns in Data Sets

# %%
student_mat_clean.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object')

# %%
student_por_clean.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object')

# %% [markdown]
# ## Number of Unique Columns

# %%
len(student_mat_clean.columns)
# Out:
# 33

# %%
len(student_por_clean.columns)
# Out:
# 33

# %% [markdown]
# ## Math Students Demographic

# %% [markdown]
# ### Age

# %%
student_mat_clean['age'].value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %% [markdown]
# ### Sex

# %%
student_mat_clean['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %% [markdown]
# ### Address

# %%
student_mat_clean['address'].value_counts()
# Out:
# U    307
# R     88
# Name: address, dtype: int64

# %% [markdown]
# ### Family Size

# %%
student_mat_clean['famsize'].value_counts()
# Out:
# GT3    281
# LE3    114
# Name: famsize, dtype: int64

# %% [markdown]
# ### Parent's Cohabitation Status

# %%
student_mat_clean['pstatus'].value_counts()
# Out:
# T    354
# A     41
# Name: pstatus, dtype: int64

# %% [markdown]
# ## Portugese Students Demographic

# %% [markdown]
# ### Age

# %%
student_por_clean['age'].value_counts()
# Out:
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: age, dtype: int64

# %% [markdown]
# ### Sex

# %%
student_por_clean['sex'].value_counts()
# Out:
# F    383
# M    266
# Name: sex, dtype: int64

# %% [markdown]
# ### Address

# %%
student_por_clean['address'].value_counts()
# Out:
# U    452
# R    197
# Name: address, dtype: int64

# %% [markdown]
# ### Family Size

# %%
student_por_clean['famsize'].value_counts()
# Out:
# GT3    457
# LE3    192
# Name: famsize, dtype: int64

# %% [markdown]
# ### Parent's Cohabitation Status

# %%
student_por_clean['pstatus'].value_counts()
# Out:
# T    569
# A     80
# Name: pstatus, dtype: int64

# %% [markdown]
# # Correlation Between Data

# %% [markdown]
# ### Does failure (in terms of academic performance) and lack of family support lead to a higher alcohol consumption?

# %%
sm_failure_table = student_mat_clean.groupby('failures')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_failure_table)
# Out:
#     failures  dalc  frequency
# 0          0     1        232
# 1          0     2         50
# 2          0     3         17
# 3          0     5          7
# 4          0     4          6
# 5          1     1         29
# 6          1     2         12
# 7          1     3          6
# 8          1     4          2
# 9          1     5          1
# 10         2     2          8
# 11         2     1          7
# 12         2     3          1
# 13         2     4          1
# 14         3     1          8
# 15         3     2          5
# 16         3     3          2
# 17         3     5          1

# %%
student_mat_clean[['famsup', 'dalc']].value_counts()
# Out:
# famsup  dalc
# True    1       173
# False   1       103
# True    2        46
# False   2        29
#         3        15
# True    3        11
#         5         7
#         4         5
# False   4         4
#         5         2
# dtype: int64

# %%
sp_failure_table = student_por_clean.groupby('failures')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_failure_table)
# Out:
#     failures  dalc  frequency
# 0          0     1        392
# 1          0     2        102
# 2          0     3         31
# 3          0     5         13
# 4          0     4         11
# 5          1     1         39
# 6          1     2         15
# 7          1     3          9
# 8          1     4          6
# 9          1     5          1
# 10         2     1         10
# 11         2     2          3
# 12         2     3          2
# 13         2     5          1
# 14         3     1         10
# 15         3     5          2
# 16         3     2          1
# 17         3     3          1

# %%
student_por_clean[['famsup', 'dalc']].value_counts()
# Out:
# famsup  dalc
# True    1       280
# False   1       171
# True    2        77
# False   2        44
#         3        24
# True    3        19
#         5        14
# False   4         9
# True    4         8
# False   5         3
# dtype: int64

# %% [markdown]
# ### Does internet usage lead to higher alcohol consumption tendencies?

# %%
student_mat_clean[['internet', 'dalc']].value_counts()
# Out:
# internet  dalc
# True      1       228
#           2        64
# False     1        48
# True      3        21
# False     2        11
# True      5         9
#           4         7
# False     3         5
#           4         2
# dtype: int64

# %%
student_por_clean[['internet', 'dalc']].value_counts()
# Out:
# internet  dalc
# True      1       342
# False     1       109
# True      2        95
#           3        32
# False     2        26
# True      5        15
#           4        14
# False     3        11
#           4         3
#           5         2
# dtype: int64

# %% [markdown]
# ### Is there a correlation of high alcohol consumption with lengthier free hours (freetime)? If not, would this be true otherwise, with shorter free hours?

# %%
sm_freetime_table = student_mat_clean.groupby('freetime')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_freetime_table)
# Out:
#     freetime  dalc  frequency
# 0          1     1         17
# 1          1     2          1
# 2          1     3          1
# 3          2     1         51
# 4          2     2          9
# 5          2     3          3
# 6          2     4          1
# 7          3     1        113
# 8          3     2         33
# 9          3     3          6
# 10         3     4          3
# 11         3     5          2
# 12         4     1         73
# 13         4     2         23
# 14         4     3         12
# 15         4     5          4
# 16         4     4          3
# 17         5     1         22
# 18         5     2          9
# 19         5     3          4
# 20         5     5          3
# 21         5     4          2

# %%
sp_freetime_table = student_por_clean.groupby('freetime')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_freetime_table)
# Out:
#     freetime  dalc  frequency
# 0          1     1         32
# 1          1     2          6
# 2          1     3          3
# 3          1     4          2
# 4          1     5          2
# 5          2     1         82
# 6          2     2         15
# 7          2     3          7
# 8          2     4          3
# 9          3     1        187
# 10         3     2         47
# 11         3     3          7
# 12         3     4          5
# 13         3     5          5
# 14         4     1        107
# 15         4     2         41
# 16         4     3         21
# 17         4     4          5
# 18         4     5          4
# 19         5     1         43
# 20         5     2         12
# 21         5     5          6
# 22         5     3          5
# 23         5     4          2

# %% [markdown]
# ### Do students with separated parents have a greater tendency to consume alcohol? If yes, do they more frequently consume alcohol during weekdays or during weekends?

# %%
student_mat_clean[['pstatus', 'dalc']].value_counts()
# Out:
# pstatus  dalc
# T        1       247
#          2        70
# A        1        29
# T        3        22
#          5         8
#          4         7
# A        2         5
#          3         4
#          4         2
#          5         1
# dtype: int64

# %%
student_mat_clean[['pstatus', 'walc']].value_counts()
# Out:
# pstatus  walc
# T        1       131
#          2        79
#          3        77
#          4        43
#          5        24
# A        1        20
#          4         8
#          2         6
#          5         4
#          3         3
# dtype: int64

# %%
student_por_clean[['pstatus', 'dalc']].value_counts()
# Out:
# pstatus  dalc
# T        1       389
#          2       112
# A        1        62
# T        3        37
#          4        16
#          5        15
# A        2         9
#          3         6
#          5         2
#          4         1
# dtype: int64

# %%
student_por_clean[['pstatus', 'walc']].value_counts()
# Out:
# pstatus  walc
# T        1       208
#          2       133
#          3       111
#          4        75
#          5        42
# A        1        39
#          2        17
#          4        12
#          3         9
#          5         3
# dtype: int64

# %% [markdown]
# ### Do students in romantic relationships have a higher tendency of greater alcohol consumption?

# %%
student_mat_clean[['romantic', 'dalc']].value_counts()
# Out:
# romantic  dalc
# False     1       182
# True      1        94
# False     2        51
# True      2        24
# False     3        21
#           4         5
# True      3         5
#           5         5
# False     5         4
# True      4         4
# dtype: int64

# %%
student_por_clean[['romantic', 'dalc']].value_counts()
# Out:
# romantic  dalc
# False     1       289
# True      1       162
# False     2        75
# True      2        46
# False     3        32
# True      3        11
#           4        10
#           5        10
# False     4         7
#           5         7
# dtype: int64

# %% [markdown]
# ### Do students with bigger families have a higher tendency of greater alcohol consumption?

# %%
sm_famsize_table = student_mat_clean.groupby('famsize')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_famsize_table)
# Out:
#   famsize  dalc  frequency
# 0     GT3     1        208
# 1     GT3     2         47
# 2     GT3     3         14
# 3     GT3     5          8
# 4     GT3     4          4
# 5     LE3     1         68
# 6     LE3     2         28
# 7     LE3     3         12
# 8     LE3     4          5
# 9     LE3     5          1

# %%
sp_famsize_table = student_por_clean.groupby('famsize')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_famsize_table)
# Out:
#   famsize  dalc  frequency
# 0     GT3     1        328
# 1     GT3     2         80
# 2     GT3     3         26
# 3     GT3     5         12
# 4     GT3     4         11
# 5     LE3     1        123
# 6     LE3     2         41
# 7     LE3     3         17
# 8     LE3     4          6
# 9     LE3     5          5

# %% [markdown]
# ### Do students with higher engagement in extracurricular activities tend to have higher alcohol consumption?

# %%
sm_activities_table = student_mat_clean.groupby('activities')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_activities_table)
# Out:
#    activities  dalc  frequency
# 0       False     1        129
# 1       False     2         39
# 2       False     3         16
# 3       False     4          6
# 4       False     5          4
# 5        True     1        147
# 6        True     2         36
# 7        True     3         10
# 8        True     5          5
# 9        True     4          3

# %%
sp_activities_table = student_por_clean.groupby('activities')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_activities_table)
# Out:
#    activities  dalc  frequency
# 0       False     1        230
# 1       False     2         66
# 2       False     3         24
# 3       False     4          9
# 4       False     5          5
# 5        True     1        221
# 6        True     2         55
# 7        True     3         19
# 8        True     5         12
# 9        True     4          8

# %% [markdown]
# ### Does the student’s alcohol consumption have an effect on their health? If yes, is it directly or indirectly proportional to the condition of the student’s health?

# %%
student_mat_clean[['dalc', 'walc', 'health']].value_counts()
# Out:
# dalc  walc  health
# 1     1     5         46
#             3         41
#             4         28
#       2     5         23
#       1     1         20
#                       ..
# 3     3     2          1
#             1          1
#       2     5          1
# 1     5     5          1
# 3     5     3          1
# Length: 66, dtype: int64

# %%
student_por_clean[['dalc', 'walc', 'health']].value_counts()
# Out:
# dalc  walc  health
# 1     1     5         77
#             3         54
#             4         43
#       2     5         43
#       1     1         41
#                       ..
# 4     2     5          1
#       1     1          1
# 3     5     2          1
# 1     5     3          1
# 3     5     1          1
# Length: 74, dtype: int64

# %% [markdown]
# ### Does the student’s alcohol consumption affect their attendance in school? If so, does it lead to greater absences in their classes?

# %%
student_mat_clean[['dalc', 'walc', 'absences']].value_counts()
# Out:
# dalc  walc  absences
# 1     1     0           57
#             2           26
#       2     0           19
#       1     4           18
#       2     2           14
#                         ..
# 2     3     3            1
# 1     2     23           1
# 2     3     1            1
# 1     2     25           1
# 2     4     16           1
# Length: 134, dtype: int64

# %%
student_por_clean[['dalc', 'walc', 'absences']].value_counts()
# Out:
# dalc  walc  absences
# 1     1     0           101
#             2            46
#       2     0            42
#       1     4            40
#       3     0            25
#                        ...
#       2     9             1
#             11            1
# 2     3     32            1
#             30            1
#       2     26            1
# Length: 137, dtype: int64

# %% [markdown]
# ### Does the student’s frequency in going out promote their alcohol consumption? Is there a relationship between the two?

# %%
sm_goout_d_table = student_mat_clean.groupby('goout')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_goout_d_table)
# Out:
#     goout  dalc  frequency
# 0       1     1         20
# 1       1     2          2
# 2       1     3          1
# 3       2     1         81
# 4       2     2         16
# 5       2     3          3
# 6       2     4          2
# 7       2     5          1
# 8       3     1         99
# 9       3     2         22
# 10      3     3          6
# 11      3     5          2
# 12      3     4          1
# 13      4     1         50
# 14      4     2         23
# 15      4     3          9
# 16      4     4          4
# 17      5     1         26
# 18      5     2         12
# 19      5     3          7
# 20      5     5          6
# 21      5     4          2

# %%
sm_goout_w_table = student_mat_clean.groupby('goout')['walc'].value_counts().reset_index(name = 'frequency')

print(sm_goout_w_table)
# Out:
#     goout  walc  frequency
# 0       1     1         15
# 1       1     2          4
# 2       1     3          2
# 3       1     4          2
# 4       2     1         54
# 5       2     2         29
# 6       2     3         12
# 7       2     4          6
# 8       2     5          2
# 9       3     1         47
# 10      3     2         37
# 11      3     3         35
# 12      3     4          7
# 13      3     5          4
# 14      4     1         26
# 15      4     4         23
# 16      4     3         22
# 17      4     2          9
# 18      4     5          6
# 19      5     5         16
# 20      5     4         13
# 21      5     1          9
# 22      5     3          9
# 23      5     2          6

# %%
sp_goout_d_table = student_por_clean.groupby('goout')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_goout_d_table)
# Out:
#     goout  dalc  frequency
# 0       1     1         42
# 1       1     2          4
# 2       1     3          2
# 3       2     1        115
# 4       2     2         21
# 5       2     3          5
# 6       2     4          3
# 7       2     5          1
# 8       3     1        149
# 9       3     2         39
# 10      3     3         10
# 11      3     5          4
# 12      3     4          3
# 13      4     1         84
# 14      4     2         36
# 15      4     3         14
# 16      4     4          5
# 17      4     5          2
# 18      5     1         61
# 19      5     2         21
# 20      5     3         12
# 21      5     5         10
# 22      5     4          6

# %%
sp_goout_w_table = student_por_clean.groupby('goout')['walc'].value_counts().reset_index(name = 'frequency')

print(sp_goout_w_table)
# Out:
#     goout  walc  frequency
# 0       1     1         33
# 1       1     2          7
# 2       1     3          4
# 3       1     4          3
# 4       1     5          1
# 5       2     1         75
# 6       2     2         39
# 7       2     3         21
# 8       2     4          7
# 9       2     5          3
# 10      3     1         76
# 11      3     2         61
# 12      3     3         45
# 13      3     4         18
# 14      3     5          5
# 15      4     1         43
# 16      4     4         33
# 17      4     3         30
# 18      4     2         25
# 19      4     5         10
# 20      5     4         26
# 21      5     5         26
# 22      5     1         20
# 23      5     3         20
# 24      5     2         18

# %% [markdown]
# ### Does the student’s age affect the frequency of their alcohol consumption?

# %%
sm_age_table = student_mat_clean.groupby('age')['dalc'].value_counts().reset_index(name = 'frequency')

print(sm_age_table)
# Out:
#     age  dalc  frequency
# 0    15     1         62
# 1    15     2         14
# 2    15     3          4
# 3    15     4          1
# 4    15     5          1
# 5    16     1         76
# 6    16     2         18
# 7    16     3          6
# 8    16     5          3
# 9    16     4          1
# 10   17     1         65
# 11   17     2         22
# 12   17     3          6
# 13   17     4          3
# 14   17     5          2
# 15   18     1         54
# 16   18     2         18
# 17   18     3          5
# 18   18     4          3
# 19   18     5          2
# 20   19     1         17
# 21   19     3          4
# 22   19     2          3
# 23   20     1          2
# 24   20     4          1
# 25   21     3          1
# 26   22     5          1

# %%
sp_age_table = student_por_clean.groupby('age')['dalc'].value_counts().reset_index(name = 'frequency')

print(sp_age_table)
# Out:
#     age  dalc  frequency
# 0    15     1         81
# 1    15     2         22
# 2    15     3          7
# 3    15     4          1
# 4    15     5          1
# 5    16     1        130
# 6    16     2         33
# 7    16     3          8
# 8    16     4          3
# 9    16     5          3
# 10   17     1        119
# 11   17     2         36
# 12   17     3         15
# 13   17     5          6
# 14   17     4          3
# 15   18     1         96
# 16   18     2         25
# 17   18     3          8
# 18   18     4          6
# 19   18     5          5
# 20   19     1         20
# 21   19     3          5
# 22   19     4          4
# 23   19     2          3
# 24   20     1          4
# 25   20     2          2
# 26   21     1          1
# 27   21     5          1
# 28   22     5          1

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Dalc Graph

# %%
dalc_graph = student_mat_clean.value_counts('dalc')

dalc_graph
# Out:
# dalc
# 1    276
# 2     75
# 3     26
# 4      9
# 5      9
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.plot(dalc_graph.index, dalc_graph.values)
plt.title("Dalc Analysis")
plt.xlabel("Dalc Values")
plt.ylabel("Dalc Frequency")

plt.show()
